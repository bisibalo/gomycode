# %% [markdown]
# # PROJECT MODELLING PHASE

# %% [markdown]
# ### in this phase, i structured, manipulated and analyzed the dataset using the pandas library and i saved the model with pickle. then also in this notebook includes the block of codes run on VScode to create a streamlit spotify song recommendation app. in this phase i built a predictive model that prepares and structures data for use with machine learning libraries like scikit-learn to make predictions nd music recommendations for users.

# %%
import pandas as pd

# %%
songs = pd.read_csv(r"C:\Users\HP\Downloads\archive(4)\dataset.csv")
songs
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
songs = songs.rename(columns = {'Unnamed: 0':'id'})
songs = songs.rename(columns={"track_name":"title"})

# %%
songs = songs[['id','album_name','title','track_genre']]

# %%
songs
# Out:
#             id                                         album_name  \
# 0            0                                             Comedy
# 1            1                                   Ghost (Acoustic)
# 2            2                                     To Begin Again
# 3            3  Crazy Rich Asians (Original Motion Picture Sou...
# 4            4                                            Hold On
# ...        ...                                                ...
# 113995  113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997  113997                                            Best Of
# 113998  113998                                  Change Your World
# 113999  113999                                     Miss Perfumado
#
#                              title  track_genre
# 0                           Comedy     acoustic
# 1                 Ghost - Acoustic     acoustic
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
songs['tags'] = songs['album_name'] + songs['track_genre']
songs
# Out:
#             id                                         album_name  \
# 0            0                                             Comedy
# 1            1                                   Ghost (Acoustic)
# 2            2                                     To Begin Again
# 3            3  Crazy Rich Asians (Original Motion Picture Sou...
# 4            4                                            Hold On
# ...        ...                                                ...
# 113995  113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997  113997                                            Best Of
# 113998  113998                                  Change Your World
# 113999  113999                                     Miss Perfumado
#
#                              title  track_genre  \
# 0                           Comedy     acoustic
# 1                 Ghost - Acoustic     acoustic
# ...

# %%
new_df = songs.drop(columns =['album_name','track_genre'])
new_df
# Out:
#             id                       title  \
# 0            0                      Comedy
# 1            1            Ghost - Acoustic
# 2            2              To Begin Again
# 3            3  Can't Help Falling In Love
# 4            4                     Hold On
# ...        ...                         ...
# 113995  113995         Sleep My Little Boy
# 113996  113996            Water Into Light
# 113997  113997              Miss Perfumado
# 113998  113998                     Friends
# 113999  113999                   Barbincor
#
#                                                      tags
# 0                                          Comedyacoustic
# 1                                Ghost (Acoustic)acoustic
# 2                                  To Begin Againacoustic
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                         Hold Onacoustic
# ...                                                   ...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features = 114000, stop_words ='english')
cv
# Out:
# CountVectorizer(max_features=114000, stop_words='english')

# %%
vector = cv.fit_transform(new_df['tags'].astype(str))
vector
# Out:
# <114000x64814 sparse matrix of type '<class 'numpy.int64'>'
# 	with 361370 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector, dense_output=False)

# %%
similarity
# Out:
# <114000x114000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 210709642 stored elements in Compressed Sparse Row format>

# %%
new_df[new_df['title']=='To Begin Again'].index[0]
# Out:
# 2

# %%
distance = sorted(list(enumerate(similarity[2])), reverse = True, key = lambda vector:vector[1])
for i in distance[0:5]:
    print(new_df.iloc[i[0]].title)
# Out:
# Comedy

# %%
def recommand(songs):
    index = new_df[new_df['title']==songs].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse = True, key = lambda vector:vector[1])
    for i in distance[0:5]:
        print(new_df.iloc[i[0]].title)

# %%
recommand("To Begin Again")
# Out:
# Comedy

# %% [markdown]
# # saving the model

# %%
import pickle as pk

# %%
pk.dump(new_df, open('songs.pkl', 'wb'))
pk.dump(similarity, open('similarity.pkl', 'wb'))

# %% [markdown]
# # VS CODE USED TO RUN THE STREAMLIT
#
# import streamlit as st
# import pickle
# import numpy as np
# from scipy.sparse import csr_matrix
#
# st.subheader("SPOTIFY")
# st.image("spotifydeal.jpg")
#
# # Load data
# songs = pickle.load(open("songs.pkl", 'rb'))
# similarity = pickle.load(open("similarity.pkl", 'rb'))  # Keep sparse
#
# # Ensure correct formatting
# songs["title"] = songs["title"].str.strip().str.lower()
# songs_list = songs["title"].tolist()
#
# st.header("Song Recommendation System")
# selectvalue = st.selectbox("Select a song", songs_list)
#
# def recommend(song_name):
#     song_name = song_name.strip().lower()
#
#     matching_songs = songs[songs['title'] == song_name]
#     if matching_songs.empty:
#         return ["Song not found"] * 5
#
#     index = matching_songs.index[0]
#
#     # 🔥 FIX: Use sparse format without converting to a full array
#     if isinstance(similarity, csr_matrix):
#         distances = similarity[index].toarray().flatten()  # Convert only the needed row
#     else:
#         distances = similarity[index]
#
#     distances = sorted(enumerate(distances), key=lambda x: x[1], reverse=True)
#     recommended_songs = [songs.iloc[i[0]].title for i in distances[1:6]]
#
#     return recommended_songs
#
# if st.button("Show Recommendations", key="recommend_button"):
#     recommendations = recommend(selectvalue)
#
#     # Debugging output
#     st.write(f"Selected song: {selectvalue}")
#     st.write(f"Recommendations: {recommendations}")
#
#     col1, col2, col3, col4, col5 = st.columns(5)
#     for col, song in zip([col1, col2, col3, col4, col5], recommendations):
#         with col:
#             st.text(song)
