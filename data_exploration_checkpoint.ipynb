# %%
import pandas as pd

# %%
# Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'.

client_O_bills = pd.read_csv(r"C:\Users\HP\Downloads\STEG_BILLING_HISTORY.csv")
client_O_bills
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22256\1122095549.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   client_O_bills = pd.read_csv(r"C:\Users\HP\Downloads\STEG_BILLING_HISTORY.csv")
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10       1253571.0
# 4476745  train_Client_99998   2005-12-19          10       1253571.0
# 4476746  train_Client_99999   1996-09-25          11        560948.0
# ...

# %%
# first 10 lines
client_O_bills.head(11)
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
#
# ...

# %%
# What is the data type of the 'client_0_bills' variable ?
type(client_O_bills)
# Out:
# pandas.core.frame.DataFrame

# %%
client_O_bills.dtypes
# Out:
# client_id                object
# invoice_date             object
# tarif_type                int64
# counter_number          float64
# counter_statue           object
# counter_code              int64
# reading_remarque        float64
# counter_coefficient       int64
# consommation_level_1      int64
# consommation_level_2      int64
# consommation_level_3      int64
# consommation_level_4      int64
# old_index                 int64
# new_index                 int64
# months_number             int64
# counter_type             object
# dtype: object

# %% [markdown]
# - Display the general information of the dataset and try to answer the following questions :
#
# - How many rows and columns do we have in this dataset ?
# - How many categorical features are present in the dataset ?
# -  How much memory space does the dataset consume ?

# %%
# - Display the general information of the dataset 
client_O_bills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4476749 entries, 0 to 4476748
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   int64
#  8   consommation_level_1  int64
#  9   consommation_level_2  int64
#  10  consommation_level_3  int64
#  11  consommation_level_4  int64
#  12  old_index             int64
#  13  new_index             int64
#  14  months_number         int64
#  15  counter_type          object
# dtypes: float64(2), int64(10), object(4)
# memory usage: 546.5+ MB

# %%
# - How many rows and columns do we have in this dataset ?
num_rows,num_columns = client_O_bills.shape
print(f'There are {num_rows} rows and {num_columns} columnsin this dataset')
# Out:
# There are 4476749 rows and 16 columnsin this dataset

# %%
# How much memory space do they consume
memory_usage = client_O_bills.memory_usage(deep=True).sum()
print(f'Memory usage: {memory_usage} bytes')
# Out:
# Memory usage: 1392139331 bytes

# %%
# check for missing values
print(client_O_bills.isnull())
# Out:
#          client_id  invoice_date  tarif_type  counter_number  counter_statue  \
# 0            False         False       False           False           False
# 1            False         False       False           False           False
# 2            False         False       False           False           False
# 3            False         False       False           False           False
# 4            False         False       False           False           False
# ...            ...           ...         ...             ...             ...
# 4476744      False         False       False           False           False
# 4476745      False         False       False           False           False
# 4476746      False         False       False           False           False
# 4476747      False         False       False           False           False
# 4476748      False         False       False           False           False
#
# ...

# %%
# Descriptive analysis
descriptive_stats = client_O_bills.describe()
descriptive_stats.head()
# Out:
#          tarif_type  counter_number  counter_code  reading_remarque  \
# count  4.476749e+06    4.476701e+06  4.476749e+06      4.472218e+06
# mean   2.012804e+01    1.230595e+11  1.724884e+02      7.321713e+00
# std    1.347256e+01    1.657276e+12  1.338871e+02      1.571859e+00
# min    8.000000e+00    0.000000e+00  0.000000e+00      5.000000e+00
# 25%    1.100000e+01    1.211080e+05  5.000000e+00      6.000000e+00
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count         4.476749e+06          4.476749e+06          4.476749e+06
# mean          1.003040e+00          4.109795e+02          1.093225e+02
# std           3.083466e-01          7.573080e+02          1.220123e+03
# min           0.000000e+00          0.000000e+00          0.000000e+00
# 25%           1.000000e+00          7.900000e+01          0.000000e+00
#
#        consommation_level_3  consommation_level_4     old_index     new_index  \
# ...

# %%
# Method 1: Using boolean indexing
client_0_records_1 = client_O_bills[client_O_bills['client_id'] == 'train_Client_0']

# Method 2: Using query method
client_0_records_2 = client_O_bills.query("client_id == 'train_Client_0'")
client_0_records_1
# Out:
#          client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0              0
# 1   train_Client_0   2013-03-29          11       1335667.0              0
# 2   train_Client_0   2015-03-23          11       1335667.0              0
# 3   train_Client_0   2015-07-13          11       1335667.0              0
# 4   train_Client_0   2016-11-17          11       1335667.0              0
# 5   train_Client_0   2017-07-17          11       1335667.0              0
# 6   train_Client_0   2018-12-07          11       1335667.0              0
# 7   train_Client_0   2019-03-19          11       1335667.0              0
# 8   train_Client_0   2011-07-22          11       1335667.0              0
# 9   train_Client_0   2011-11-22          11       1335667.0              0
# 10  train_Client_0   2008-11-25          11       1335667.0              0
# ...

# %%
# Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.

from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
client_O_bills['counter_type_encoded'] = label_encoder.fit_transform(client_O_bills['counter_type'])

# %%
# Delete the 'counter_statue' feature from the Dataframe
client_O_bills.drop(columns=['counter_statue'], inplace=True)

#I EXECUTED THIS AGAIN AFTER I ALREADY DELETED IT,REASON FOR THE ERROR MESSAGE BELOW
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Delete the 'counter_statue' feature from the Dataframe
# ----> 2 client_O_bills.drop(columns=['counter_statue'], inplace=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...
