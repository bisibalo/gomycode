# %% [markdown]
# Instructions
#
# Steps :
#
# Web Scraping:
#
#     Utilize Python libraries such as BeautifulSoup to scrape product information from the online retailer's website.
#     Collect data attributes including product names, categories, prices, availability status, and promotional details.
#
#     Data Cleaning:
#
#         Address missing or inconsistent data entries, such as absent prices or ambiguous product descriptions.
#         Standardize text fields to ensure uniformity in product names and categories.
#
#     Data Transformation:
#
#         Convert price data into numerical formats for analysis.
#         Categorize products into hierarchical groups (e.g., Electronics > Mobile Phones > Smartphones).
#
#     Data Analysis:
#
#         Conduct exploratory data analysis (EDA) to uncover insights:
#             Identify average pricing within each product category.
#             Detect seasonal or promotional pricing patterns.
#             Assess product availability trends over time.
#
#     Data Visualization:
#
#         Employ visualization library Plotly to create some charts.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
#webscrapping the jumia website for a single product
url ="https://www.jumia.com.ng/dr-teals-aroma-energy-body-scrub-orange-454g-325477595.html"
jumia = requests.get(url)
jumia.content
# Out:
# b'<!DOCTYPE html><html lang="en" dir="ltr"><head><meta charset="utf-8"/><title>Dr Teal\'s Aroma Energy Body Scrub Orange 454g | Jumia Nigeria</title><meta property="og:type" content="product"/><meta property="og:site_name" content="Jumia Nigeria"/><meta property="og:title" content="Aroma Energy Body Scrub Orange 454g"/><meta property="og:description" content="Bath and Body Aromatherapy Energy Orange Ginger Pumice Body Scrub - 11.5 oz / 326 g. What it smells like: a fruity, spiced refresher. Fragrance notes: orange oil (invigorates and uplifts) and ginger oil (energizes your senses). What it does: buffs and exfoliates skin to leave you feeling conditioned and clean.\nGentle enough to use every day, this foaming body scrub with exfoliating walnut shells and conditioning Vitamin E cleanses and softens skin. An aromatherapy blend of essential oils and natural ingredients enhances body, mind &amp;amp; mood. Breathe deeply for best results"/><meta property="og:url" content="https://www.jumia.com.ng/dr-teals-aroma-energy-body-scrub-orange-454g-325477595.html"/><meta property="og:image" content="https://ng.jumia.is/unsafe/fit-in/500x500/filters:fill(white)/product/59/5774523/1.jpg?5602"/><meta property="og:locale" content="en_NG"/><meta name="title" content="Dr Teal\'s Aroma Energy Body Scrub Orange 454g | Jumia Nigeria"/><meta name="robots" content="index,follow"/><meta name="description" content="Get the Aroma Energy Body Scrub Orange 454g online at Jumia Nigeria and other Dr Teal\'s Body Washes on Jumia Nigeria \xe2\x9c\x93 Price in Naira \xe2\x9c\x93 Enjoy cash on delivery - Shop Now!"/><link rel="alternate" href="android-app://com.jumia.android/JUMIA/NG/d/DR074ST5Y2ZQKNAFAMZ?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.com.ng%2Fdr-teals-aroma-energy-body-scrub-orange-454g-325477595.html"/><link rel="canonical" href="https://www.jumia.com.ng/dr-teals-aroma-energy-body-scrub-orange-454g-325477595.html"/><meta property="fb:app_id" content="728795990650684"/><meta property="fb:pages" content="291297097615087"/><meta name="google-site-verification" content="4vr0StQ8YkyEzgDxkC_mgx0UMSH2xM3vkOaRpaMEjWM"/><meta name="google-site-verification" content="VeavdmtsHUH8fIEGpu4eeF-ryLp5ZXVUOmWmXWzV11I"/><meta name="msvalidate.01" content="66DCE7076C4C56245BAB83C687510491"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><meta name="application-name" content="Jumia"/><meta name="theme-color" content="#ffffff"/><link rel="manifest" crossorigin="use-credentials" href="https://www.jumia.com.ng/assets_he/manifest/jumia/ng.2bc74913.json"/><link rel="stylesheet" href="https://www.jumia.com.ng/assets_he/css/main.90c53fdb.css"/><link rel="icon" type="image/ico" sizes="any" href="https://www.jumia.com.ng/assets_he/favicon.87f00114.ico"/><link rel="icon" type="image/svg+xml" href="https://www.jumia.com.ng/assets_he/favicon.adbd556a.svg"/><link rel="preconnect dns-prefetch" href="//bam.nr-data.net"/><link rel="preconnect dns-prefetch" href="//js-agent.newrelic.com"/><link rel="preconnect dns-prefetch" href="//www.google-analytics.com"/><link rel="preconnect dns-prefetch" href="//www.googletagmanager.com"/><link rel="preconnect dns-prefetch" href="//www.facebook.com"/><link rel="preconnect dns-prefetch" href="//connect.facebook.net"/><link rel="preconnect dns-prefetch" href="//static.criteo.net"/><link rel="preconnect dns-prefetch" href="//sslwidget.criteo.com"/><link rel="preconnect dns-prefetch" href="//dis.eu.criteo.com"/><link rel="preconnect dns-prefetch" href="//creativecdn.com"/><link rel="dns-prefetch" href="https://ng.jumia.is"/></head><body><script type=\'text/javascript\'>window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"702890399","agentToken":null,"applicationTime":12.656562,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFmZ ...

# %%
# Collect data attributes including product names, categories, prices, availability status, and promotional details.
jm=BeautifulSoup(jumia.content,'html.parser')
jm.prettify()
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Dr Teal\'s Aroma Energy Body Scrub Orange 454g | Jumia Nigeria\n  </title>\n  <meta content="product" property="og:type"/>\n  <meta content="Jumia Nigeria" property="og:site_name"/>\n  <meta content="Aroma Energy Body Scrub Orange 454g" property="og:title"/>\n  <meta content="Bath and Body Aromatherapy Energy Orange Ginger Pumice Body Scrub - 11.5 oz / 326 g. What it smells like: a fruity, spiced refresher. Fragrance notes: orange oil (invigorates and uplifts) and ginger oil (energizes your senses). What it does: buffs and exfoliates skin to leave you feeling conditioned and clean.\nGentle enough to use every day, this foaming body scrub with exfoliating walnut shells and conditioning Vitamin E cleanses and softens skin. An aromatherapy blend of essential oils and natural ingredients enhances body, mind &amp;amp; mood. Breathe deeply for best results" property="og:description"/>\n  <meta content="https://www.jumia.com.ng/dr-teals-aroma-energy-body-scrub-orange-454g-325477595.html" property="og:url"/>\n  <meta content="https://ng.jumia.is/unsafe/fit-in/500x500/filters:fill(white)/product/59/5774523/1.jpg?5602" property="og:image"/>\n  <meta content="en_NG" property="og:locale"/>\n  <meta content="Dr Teal\'s Aroma Energy Body Scrub Orange 454g | Jumia Nigeria" name="title"/>\n  <meta content="index,follow" name="robots"/>\n  <meta content="Get the Aroma Energy Body Scrub Orange 454g online at Jumia Nigeria and other Dr Teal\'s Body Washes on Jumia Nigeria ✓ Price in Naira ✓ Enjoy cash on delivery - Shop Now!" name="description"/>\n  <link href="android-app://com.jumia.android/JUMIA/NG/d/DR074ST5Y2ZQKNAFAMZ?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.com.ng%2Fdr-teals-aroma-energy-body-scrub-orange-454g-325477595.html" rel="alternate"/>\n  <link href="https://www.jumia.com.ng/dr-teals-aroma-energy-body-scrub-orange-454g-325477595.html" rel="canonical"/>\n  <meta content="728795990650684" property="fb:app_id"/>\n  <meta content="291297097615087" property="fb:pages"/>\n  <meta content="4vr0StQ8YkyEzgDxkC_mgx0UMSH2xM3vkOaRpaMEjWM" name="google-site-verification"/>\n  <meta content="VeavdmtsHUH8fIEGpu4eeF-ryLp5ZXVUOmWmXWzV11I" name="google-site-verification"/>\n  <meta content="66DCE7076C4C56245BAB83C687510491" name="msvalidate.01"/>\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <meta content="Jumia" name="application-name"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <link crossorigin="use-credentials" href="https://www.jumia.com.ng/assets_he/manifest/jumia/ng.2bc74913.json" rel="manifest"/>\n  <link href="https://www.jumia.com.ng/assets_he/css/main.90c53fdb.css" rel="stylesheet"/>\n  <link href="https://www.jumia.com.ng/assets_he/favicon.87f00114.ico" rel="icon" sizes="any" type="image/ico"/>\n  <link href="https://www.jumia.com.ng/assets_he/favicon.adbd556a.svg" rel="icon" type="image/svg+xml"/>\n  <link href="//bam.nr-data.net" rel="preconnect dns-prefetch"/>\n  <link href="//js-agent.newrelic.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.facebook.com" rel="preconnect dns-prefetch"/>\n  <link href="//connect.facebook.net" rel="preconnect dns-prefetch"/>\n  <link href="//static.criteo.net" rel="preconnect dns-prefetch"/>\n  <link href="//sslwidget.criteo.com" rel="preconnect dns-prefetch"/>\n  <link href="//dis.eu.criteo.com" rel="preconnect dns-prefetch"/>\n  <link href="//creativecdn.com" rel="preconnect dns-prefetch"/>\n  <link href="https://ng.jumia.is" rel="dns-prefetch"/>\n </head>\n <body>\n  <script type="text/javascript">\n   window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net ...

# %%
jm.find_all("title")
# Out:
# [<title>Dr Teal's Aroma Energy Body Scrub Orange 454g | Jumia Nigeria</title>]

# %%
prd_name = jm.h1.text
# Out:
# "Dr Teal's Aroma Energy Body Scrub Orange 454g"

# %%
prd_category=jm.find_all(class_="cbs")[1].text

# %%
prd_category
# Out:
# 'Health & Beauty'

# %%
prd_price=jm.find(class_="-b -ubpt -tal -fs24 -prxs")
jmmm.text
# Out:
# '₦ 12,540'

# %%
prd_image=jm.find(class_="-fw -fh")
prd_image
# Out:
# <img alt="product_image_name-Dr Teal's-Aroma Energy Body Scrub Orange 454g-1" class="-fw -fh" data-lazy-slide="true" data-src="https://ng.jumia.is/unsafe/fit-in/500x500/filters:fill(white)/product/59/5774523/1.jpg?5602" src="..."/>

# %%
# web scrapping for a category of products
link = "https://www.jumia.com.ng/body-washes/"
link_read = requests.get(link)
link_read.content
# Out:
# b'<!DOCTYPE html><html lang="en" dir="ltr"><head><meta charset="utf-8"/><title>Cleansers Body Washes | Buy Cleansers Body Washes Online in Nigeria | Jumia NG</title><meta property="og:type" content="product"/><meta property="og:site_name" content="Jumia Nigeria"/><meta property="og:title" content="Cleansers Body Washes | Buy Cleansers Body Washes Online in Nigeria | Jumia NG"/><meta property="og:description" content="Shop for Cleansers Body Washes online on Jumia Nigeria. Discover a great selection of Cleansers Body Washes \xe2\x9c\x93 Best prices in Nigeria \xe2\x9c\x93 Enjoy cash on delivery - Order Now!"/><meta property="og:url" content="/body-washes/"/><meta property="og:image" content="https://ng.jumia.is/cms/jumialogonew.png"/><meta property="og:locale" content="en_NG"/><meta name="title" content="Cleansers Body Washes | Buy Cleansers Body Washes Online in Nigeria | Jumia NG"/><meta name="robots" content="index,follow"/><meta name="description" content="Shop for Cleansers Body Washes online on Jumia Nigeria. Discover a great selection of Cleansers Body Washes \xe2\x9c\x93 Best prices in Nigeria \xe2\x9c\x93 Enjoy cash on delivery - Order Now!"/><link rel="alternate" href="android-app://com.jumia.android/JUMIA/NG/c/body-washes?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.com.ng%2Fbody-washes%2F"/><link rel="canonical" href="https://www.jumia.com.ng/body-washes/"/><link rel="next" href="https://www.jumia.com.ng/body-washes/?page=2"/><meta property="fb:app_id" content="728795990650684"/><meta property="fb:pages" content="291297097615087"/><meta name="google-site-verification" content="4vr0StQ8YkyEzgDxkC_mgx0UMSH2xM3vkOaRpaMEjWM"/><meta name="google-site-verification" content="VeavdmtsHUH8fIEGpu4eeF-ryLp5ZXVUOmWmXWzV11I"/><meta name="msvalidate.01" content="66DCE7076C4C56245BAB83C687510491"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><meta name="application-name" content="Jumia"/><meta name="theme-color" content="#ffffff"/><link rel="manifest" crossorigin="use-credentials" href="https://www.jumia.com.ng/assets_he/manifest/jumia/ng.2bc74913.json"/><link rel="stylesheet" href="https://www.jumia.com.ng/assets_he/css/main.90c53fdb.css"/><link rel="icon" type="image/ico" sizes="any" href="https://www.jumia.com.ng/assets_he/favicon.87f00114.ico"/><link rel="icon" type="image/svg+xml" href="https://www.jumia.com.ng/assets_he/favicon.adbd556a.svg"/><link rel="preconnect dns-prefetch" href="//bam.nr-data.net"/><link rel="preconnect dns-prefetch" href="//js-agent.newrelic.com"/><link rel="preconnect dns-prefetch" href="//www.google-analytics.com"/><link rel="preconnect dns-prefetch" href="//www.googletagmanager.com"/><link rel="preconnect dns-prefetch" href="//www.facebook.com"/><link rel="preconnect dns-prefetch" href="//connect.facebook.net"/><link rel="preconnect dns-prefetch" href="//static.criteo.net"/><link rel="preconnect dns-prefetch" href="//sslwidget.criteo.com"/><link rel="preconnect dns-prefetch" href="//dis.eu.criteo.com"/><link rel="preconnect dns-prefetch" href="//creativecdn.com"/><link rel="dns-prefetch" href="https://ng.jumia.is"/></head><body><script type=\'text/javascript\'>window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"702890399","agentToken":null,"applicationTime":55.6054,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFnVUFgMOVlIWHUY0LWpi","queueTime":0,"ttGuid":"ff9c43474fcba8a2"}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"718362032",accountID:"67325",trustKey:"1300143",xpid:"UgEEU1NADwMCXFhSBAgO",licenseKey:"b76de0635f",applicationID:"702890399"};;/*! For license information please see nr-loader-spa-1.278.2.min.js.LICENSE.txt */\n(()=>{var  ...

# %%
res=BeautifulSoup(link_read.content,"html.parser")
res.prettify()
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Cleansers Body Washes | Buy Cleansers Body Washes Online in Nigeria | Jumia NG\n  </title>\n  <meta content="product" property="og:type"/>\n  <meta content="Jumia Nigeria" property="og:site_name"/>\n  <meta content="Cleansers Body Washes | Buy Cleansers Body Washes Online in Nigeria | Jumia NG" property="og:title"/>\n  <meta content="Shop for Cleansers Body Washes online on Jumia Nigeria. Discover a great selection of Cleansers Body Washes ✓ Best prices in Nigeria ✓ Enjoy cash on delivery - Order Now!" property="og:description"/>\n  <meta content="/body-washes/" property="og:url"/>\n  <meta content="https://ng.jumia.is/cms/jumialogonew.png" property="og:image"/>\n  <meta content="en_NG" property="og:locale"/>\n  <meta content="Cleansers Body Washes | Buy Cleansers Body Washes Online in Nigeria | Jumia NG" name="title"/>\n  <meta content="index,follow" name="robots"/>\n  <meta content="Shop for Cleansers Body Washes online on Jumia Nigeria. Discover a great selection of Cleansers Body Washes ✓ Best prices in Nigeria ✓ Enjoy cash on delivery - Order Now!" name="description"/>\n  <link href="android-app://com.jumia.android/JUMIA/NG/c/body-washes?utm_source=google&amp;utm_medium=organic&amp;adjust_tracker=j1hd8h&amp;adjust_campaign=GOOGLE_SEARCH&amp;adjust_adgroup=https%3A%2F%2Fwww.jumia.com.ng%2Fbody-washes%2F" rel="alternate"/>\n  <link href="https://www.jumia.com.ng/body-washes/" rel="canonical"/>\n  <link href="https://www.jumia.com.ng/body-washes/?page=2" rel="next"/>\n  <meta content="728795990650684" property="fb:app_id"/>\n  <meta content="291297097615087" property="fb:pages"/>\n  <meta content="4vr0StQ8YkyEzgDxkC_mgx0UMSH2xM3vkOaRpaMEjWM" name="google-site-verification"/>\n  <meta content="VeavdmtsHUH8fIEGpu4eeF-ryLp5ZXVUOmWmXWzV11I" name="google-site-verification"/>\n  <meta content="66DCE7076C4C56245BAB83C687510491" name="msvalidate.01"/>\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <meta content="Jumia" name="application-name"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <link crossorigin="use-credentials" href="https://www.jumia.com.ng/assets_he/manifest/jumia/ng.2bc74913.json" rel="manifest"/>\n  <link href="https://www.jumia.com.ng/assets_he/css/main.90c53fdb.css" rel="stylesheet"/>\n  <link href="https://www.jumia.com.ng/assets_he/favicon.87f00114.ico" rel="icon" sizes="any" type="image/ico"/>\n  <link href="https://www.jumia.com.ng/assets_he/favicon.adbd556a.svg" rel="icon" type="image/svg+xml"/>\n  <link href="//bam.nr-data.net" rel="preconnect dns-prefetch"/>\n  <link href="//js-agent.newrelic.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.facebook.com" rel="preconnect dns-prefetch"/>\n  <link href="//connect.facebook.net" rel="preconnect dns-prefetch"/>\n  <link href="//static.criteo.net" rel="preconnect dns-prefetch"/>\n  <link href="//sslwidget.criteo.com" rel="preconnect dns-prefetch"/>\n  <link href="//dis.eu.criteo.com" rel="preconnect dns-prefetch"/>\n  <link href="//creativecdn.com" rel="preconnect dns-prefetch"/>\n  <link href="https://ng.jumia.is" rel="dns-prefetch"/>\n </head>\n <body>\n  <script type="text/javascript">\n   window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"b76de0635f","applicationID":"702890399","agentToken":null,"applicationTime":55.6054,"transactionName":"NVxXYhMHChFYVUELDQwWdkMSEgsPFnVUFgMOVlIWHUY0LWpi","queueTime":0,"ttGuid":"ff9c43474fcba8a2"}; (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:true},ajax:{deny_list:["bam.nr-data.net"]},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"718362032",accountID:"67325",trustKey:"1300143",xpid:"UgEEU1NADwMCXFhSBAgO",licenseKey:" ...

# %%
from bs4 import BeautifulSoup

html = res.find_all("div", class_="info")

# Initialize the list to hold parsed dictionaries
products = []

# Parse each HTML element
for element in html:
    soup = BeautifulSoup(str(element), 'html.parser')
    
    product_name = soup.find('h3', class_='name').get_text(strip=True) if soup.find('h3', class_='name') else None
    
    price = soup.find('div', class_='prc').get_text(strip=True) if soup.find('div', class_='prc') else None
    
    category = res.find_all(class_="cbs")[3].get_text(strip=True) 
    if product_name and price:
        products.append({
            'product_name': product_name,
            'price': price,
            'category': category
                         })

skin=[]
for product in products:
    #print(product)
    skin.append(product)

# %%
skin
# Out:
# [{'product_name': "Dr Teal's Body Wash Glow & Radiance Vitamin C 24oz",
#   'price': '₦ 9,500',
#   'category': 'Skin Care'},
#  {'product_name': "Dr Teal's Dr. Teal's Shea Butter Bath & Body Oil",
#   'price': '₦ 9,340',
#   'category': 'Skin Care'},
#  {'product_name': "Dr Teal's Aroma Energy Body Scrub Orange 454g",
#   'price': '₦ 12,540',
#   'category': 'Skin Care'},
#  {'product_name': 'Dr. Rashel Vitamin C exfoliating\xa0 silky shower gel\xa0500ml',
#   'price': '₦ 8,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Cremo All Season Body Wash Rich Smooth Lively Scent Bourbon & Oak 2-pk',
#   'price': '₦ 69,000',
#   'category': 'Skin Care'},
#  {'product_name': 'SADOER Pure Natural 10x Collagen Active Anti-aging Body Wash',
#   'price': '₦ 7,500',
#   'category': 'Skin Care'},
#  {'product_name': 'Cerave Acid SA Cleanser For Rough & Bumpy Skin, Bar Soap 128g',
#   'price': '₦ 17,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Dove Caring Bath Body Almond Seed And Hibiscus Body Wash(500ml)',
#   'price': '₦ 9,500',
#   'category': 'Skin Care'},
#  {'product_name': 'SADOER Vitamin C White*ning Nourishing & Rejuvenating Body Wash',
#   'price': '₦ 7,900',
#   'category': 'Skin Care'},
#  {'product_name': 'OKAY Olay Hydrating Body Wash (Retinol) Youthful Looking Skin.',
#   'price': '₦ 33,000',
#   'category': 'Skin Care'},
#  {'product_name': 'St. Ives Vanilla and Oat Milk Pampering Body Wash - Bevy Beauty',
#   'price': '₦ 18,500',
#   'category': 'Skin Care'},
#  {'product_name': 'Cerave Acne Control Cleanser With 2% Salicylic Acid - 237ml',
#   'price': '₦ 18,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Old Spice Body Wash for Men, Fresher Fiji Scent, Fresher Collection, 16 Fluid Ounce Pack of 4',
#   'price': '₦ 65,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Dove  Men+Care Refreshing Aqua Impact Body, Face & Hair Wash 400ml',
#   'price': '₦ 40,000',
#   'category': 'Skin Care'},
#  {'product_name': 'DR RASHEL ALOE VERA essence micellar cleansing water',
#   'price': '₦ 6,500',
#   'category': 'Skin Care'},
#  {'product_name': 'BIO NATURE Healthy Glow Ultra Lightening Body Wash With Vitamin c & Niacinamide 1000ml',
#   'price': '₦ 28,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Method  Body Wash Trio, 18 Fluid Ounce (Pack of 3)',
#   'price': '₦ 85,000',
#   'category': 'Skin Care'},
#  {'product_name': 'St Ives Exfoliating Body Wash Sea Salt And Pacific Kelp 650ml',
#   'price': '₦ 17,500',
#   'category': 'Skin Care'},
#  {'product_name': 'Cremo All Season  Blue Cedar & Cyprus Body Wash - (Pack of 2)',
#   'price': '₦ 69,000',
#   'category': 'Skin Care'},
#  {'product_name': 'St Ives smoothing body wash oatmeal and Shea butter',
#   'price': '₦ 20,000',
#   'category': 'Skin Care'},
#  {'product_name': 'St. Ives Soothing Oatmeal & Shea Butter Body Wash - Hermosamartng',
#   'price': '₦ 18,500',
#   'category': 'Skin Care'},
#  {'product_name': 'Cerave SA Smoothing Cleanser & SA Smoothing Cream For Rough And Bumpy Skin',
#   'price': '₦ 24,999',
#   'category': 'Skin Care'},
#  {'product_name': 'Dove  Men+Care Refreshing Clean Comfort  Body, Face & Hair Wash 400ml',
#   'price': '₦ 40,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Dove Glowing Ritual Body Wash(500ml)',
#   'price': '₦ 13,500',
#   'category': 'Skin Care'},
#  {'product_name': 'Olay  Serums Pressed Serum Stick Brightening',
#   'price': '₦ 80,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Cremo All Season Body Wash, Sage & Citrus, 16 fl oz (Pack of 2)',
#   'price': '₦ 80,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Lubriderm  Advanced Therapy Body Wash, Unscented Nourishing Cleanser with Pro-Ceramide, Vitamin E & Pro-Vitamin B5 Gently Cleanses Itchy, Dry Skin, Fragrance Free, Hypoallergenic',
#   'price': '₦ 39,500',
#   'category': 'Skin Care'},
#  {'product_name': 'Cerave Hydrating Cleanser Hydrating Facial Cleanser Moisturiz-ing Gentle Face Wash',
#   'price': '₦ 25,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Dove Men+Care Refreshing Extra Fresh Body, Face & Hair Wash 400ml 2pcs',
#   'price': '₦ 80,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Bye Bye Blemish Dark Spot Brightening LOTION  30ml/1oz',
#   'price': '₦ 13,800',
#   'category': 'Skin Care'},
#  {'product_name': 'Black Seed Oil',
#   'price': '₦ 4,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Dove Men+Care Refreshing Extra Fresh Body, Face & Hair Wash 400ml 2pcs',
#   'price': '₦ 80,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Old Spice  Mens Body Wash, Bearglove, Long Lasting Lather, 33.4 fl oz',
#   'price': '₦ 80,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Bismid Cosmetics Bismid-Cosmetics Intensive Lightening Exfoliating Body Wash-1000ml',
#   'price': '₦ 14,999',
#   'category': 'Skin Care'},
#  {'product_name': 'Old Spice Ultimate 4 in 1 Body Hair Face and Beard Wash, Swagger Scent, 24 Fl Ounce',
#   'price': '₦ 160,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Olay  Fresh Outlast Exotic Escape Body Wash 3-Pack Gift Set - 13.5 fl. oz. Each',
#   'price': '₦ 90,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Dove  Deeply Nourishing Body Wash 500ml',
#   'price': '₦ 13,500',
#   'category': 'Skin Care'},
#  {'product_name': 'Hemani Natural Black Seed Oil 125ml',
#   'price': '₦ 7,500',
#   'category': 'Skin Care'},
#  {'product_name': 'Cerave Foaming Facial Cleanser Niacinamide Oil Control originally',
#   'price': '₦ 25,000',
#   'category': 'Skin Care'},
#  {'product_name': 'Face Facts Ceramide Foaming Cleanser 400ml',
#   'price': '₦ 16,000',
#   'category': 'Skin Care'}]

# %%
import pandas as pd

# %%
skin_df=pd.DataFrame(skin)

# %%
skin_df
# Out:
#                                          product_name      price   category
# 0   Dr Teal's Body Wash Glow & Radiance Vitamin C ...    ₦ 9,500  Skin Care
# 1    Dr Teal's Dr. Teal's Shea Butter Bath & Body Oil    ₦ 9,340  Skin Care
# 2       Dr Teal's Aroma Energy Body Scrub Orange 454g   ₦ 12,540  Skin Care
# 3   Dr. Rashel Vitamin C exfoliating  silky shower...    ₦ 8,000  Skin Care
# 4   Cremo All Season Body Wash Rich Smooth Lively ...   ₦ 69,000  Skin Care
# 5   SADOER Pure Natural 10x Collagen Active Anti-a...    ₦ 7,500  Skin Care
# 6   Cerave Acid SA Cleanser For Rough & Bumpy Skin...   ₦ 17,000  Skin Care
# 7   Dove Caring Bath Body Almond Seed And Hibiscus...    ₦ 9,500  Skin Care
# 8   SADOER Vitamin C White*ning Nourishing & Rejuv...    ₦ 7,900  Skin Care
# 9   OKAY Olay Hydrating Body Wash (Retinol) Youthf...   ₦ 33,000  Skin Care
# 10  St. Ives Vanilla and Oat Milk Pampering Body W...   ₦ 18,500  Skin Care
# 11  Cerave Acne Control Cleanser With 2% Salicylic...   ₦ 18,000  Skin Care
# 12  Old Spice Body Wash for Men, Fresher Fiji Scen...   ₦ 65,000  Skin Care
# 13  Dove  Men+Care Refreshing Aqua Impact Body, Fa...   ₦ 40,000  Skin Care
# 14  DR RASHEL ALOE VERA essence micellar cleansing...    ₦ 6,500  Skin Care
# 15  BIO NATURE Healthy Glow Ultra Lightening Body ...   ₦ 28,000  Skin Care
# 16  Method  Body Wash Trio, 18 Fluid Ounce (Pack o...   ₦ 85,000  Skin Care
# 17  St Ives Exfoliating Body Wash Sea Salt And Pac...   ₦ 17,500  Skin Care
# 18  Cremo All Season  Blue Cedar & Cyprus Body Was...   ₦ 69,000  Skin Care
# 19  St Ives smoothing body wash oatmeal and Shea b...   ₦ 20,000  Skin Care
# 20  St. Ives Soothing Oatmeal & Shea Butter Body W...   ₦ 18,500  Skin Care
# 21  Cerave SA Smoothing Cleanser & SA Smoothing Cr...   ₦ 24,999  Skin Care
# 22  Dove  Men+Care Refreshing Clean Comfort  Body,...   ₦ 40,000  Skin Care
# 23               Dove Glowing Ritual Body Wash(500ml)   ₦ 13,500  Skin Care
# 24       Olay  Serums Pressed Serum Stick Brightening   ₦ 80,000  Skin Care
# 25  Cremo All Season Body Wash, Sage & Citrus, 16 ...   ₦ 80,000  Skin Care
# 26  Lubriderm  Advanced Therapy Body Wash, Unscent...   ₦ 39,500  Skin Care
# 27  Cerave Hydrating Cleanser Hydrating Facial Cle...   ₦ 25,000  Skin Care
# 28  Dove Men+Care Refreshing Extra Fresh Body, Fac...   ₦ 80,000  Skin Care
# 29  Bye Bye Blemish Dark Spot Brightening LOTION  ...   ₦ 13,800  Skin Care
# 30                                     Black Seed Oil    ₦ 4,000  Skin Care
# 31  Dove Men+Care Refreshing Extra Fresh Body, Fac...   ₦ 80,000  Skin Care
# 32  Old Spice  Mens Body Wash, Bearglove, Long Las...   ₦ 80,000  Skin Care
# 33  Bismid Cosmetics Bismid-Cosmetics Intensive Li...   ₦ 14,999  Skin Care
# 34  Old Spice Ultimate 4 in 1 Body Hair Face and B...  ₦ 160,000  Skin Care
# 35  Olay  Fresh Outlast Exotic Escape Body Wash 3-...   ₦ 90,000  Skin Care
# 36            Dove  Deeply Nourishing Body Wash 500ml   ₦ 13,500  Skin Care
# 37                Hemani Natural Black Seed Oil 125ml    ₦ 7,500  Skin Care
# 38  Cerave Foaming Facial Cleanser Niacinamide Oil...   ₦ 25,000  Skin Care
# 39         Face Facts Ceramide Foaming Cleanser 400ml   ₦ 16,000  Skin Care

# %%
# check for missing values
skin_df.isnull().sum()
# Out:
# product_name    0
# price           0
# category        0
# dtype: int64

# %%
skin_df.dtypes
# Out:
# product_name    object
# price           object
# category        object
# dtype: object

# %%
# Convert price data into numerical formats for analysis.
skin_df['price'] = skin_df['price'].str.replace('₦', '', regex=False) 
skin_df['price'] = skin_df['price'].str.replace(',', '', regex=False)  
skin_df['price'] = pd.to_numeric(skin_df['price'])  

print(skin_df)
# Out:
#                                          product_name   price   category
# 0   Dr Teal's Body Wash Glow & Radiance Vitamin C ...    9500  Skin Care
# 1    Dr Teal's Dr. Teal's Shea Butter Bath & Body Oil    9340  Skin Care
# 2       Dr Teal's Aroma Energy Body Scrub Orange 454g   12540  Skin Care
# 3   Dr. Rashel Vitamin C exfoliating  silky shower...    8000  Skin Care
# 4   Cremo All Season Body Wash Rich Smooth Lively ...   69000  Skin Care
# 5   SADOER Pure Natural 10x Collagen Active Anti-a...    7500  Skin Care
# 6   Cerave Acid SA Cleanser For Rough & Bumpy Skin...   17000  Skin Care
# 7   Dove Caring Bath Body Almond Seed And Hibiscus...    9500  Skin Care
# 8   SADOER Vitamin C White*ning Nourishing & Rejuv...    7900  Skin Care
# 9   OKAY Olay Hydrating Body Wash (Retinol) Youthf...   33000  Skin Care
# 10  St. Ives Vanilla and Oat Milk Pampering Body W...   18500  Skin Care
# 11  Cerave Acne Control Cleanser With 2% Salicylic...   18000  Skin Care
# 12  Old Spice Body Wash for Men, Fresher Fiji Scen...   65000  Skin Care
# 13  Dove  Men+Care Refreshing Aqua Impact Body, Fa...   40000  Skin Care
# 14  DR RASHEL ALOE VERA essence micellar cleansing...    6500  Skin Care
# 15  BIO NATURE Healthy Glow Ultra Lightening Body ...   28000  Skin Care
# 16  Method  Body Wash Trio, 18 Fluid Ounce (Pack o...   85000  Skin Care
# 17  St Ives Exfoliating Body Wash Sea Salt And Pac...   17500  Skin Care
# 18  Cremo All Season  Blue Cedar & Cyprus Body Was...   69000  Skin Care
# 19  St Ives smoothing body wash oatmeal and Shea b...   20000  Skin Care
# 20  St. Ives Soothing Oatmeal & Shea Butter Body W...   18500  Skin Care
# 21  Cerave SA Smoothing Cleanser & SA Smoothing Cr...   24999  Skin Care
# 22  Dove  Men+Care Refreshing Clean Comfort  Body,...   40000  Skin Care
# 23               Dove Glowing Ritual Body Wash(500ml)   13500  Skin Care
# 24       Olay  Serums Pressed Serum Stick Brightening   80000  Skin Care
# 25  Cremo All Season Body Wash, Sage & Citrus, 16 ...   80000  Skin Care
# 26  Lubriderm  Advanced Therapy Body Wash, Unscent...   39500  Skin Care
# 27  Cerave Hydrating Cleanser Hydrating Facial Cle...   25000  Skin Care
# 28  Dove Men+Care Refreshing Extra Fresh Body, Fac...   80000  Skin Care
# 29  Bye Bye Blemish Dark Spot Brightening LOTION  ...   13800  Skin Care
# 30                                     Black Seed Oil    4000  Skin Care
# 31  Dove Men+Care Refreshing Extra Fresh Body, Fac...   80000  Skin Care
# 32  Old Spice  Mens Body Wash, Bearglove, Long Las...   80000  Skin Care
# 33  Bismid Cosmetics Bismid-Cosmetics Intensive Li...   14999  Skin Care
# 34  Old Spice Ultimate 4 in 1 Body Hair Face and B...  160000  Skin Care
# 35  Olay  Fresh Outlast Exotic Escape Body Wash 3-...   90000  Skin Care
# 36            Dove  Deeply Nourishing Body Wash 500ml   13500  Skin Care
# 37                Hemani Natural Black Seed Oil 125ml    7500  Skin Care
# 38  Cerave Foaming Facial Cleanser Niacinamide Oil...   25000  Skin Care
# 39         Face Facts Ceramide Foaming Cleanser 400ml   16000  Skin Care

# %%
# Identify average pricing within each product category.
average_prices = skin_df.groupby('category')['price'].mean().reset_index()

# %%
average_prices
# Out:
#     category     price
# 0  Skin Care  36426.95

# %%
import plotly.express as px

# %%
skin_bar=px.bar(skin_df,x="product_name",y="price",color="price",height=200)

# %%
skin_bar

# %%
skin_df.price.max()
# Out:
# 160000

# %%
skin_df.groupby('category')['price'].max()
# Out:
# category
# Skin Care    160000
# Name: price, dtype: int64

# %%
skin_bar.update_layout(title_text="skin care category", xaxis_title="product_name", yaxis_title="price")
